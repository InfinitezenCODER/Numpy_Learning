# %%
import numpy as np

# %%
a = np.array([1,2,3],dtype = np.int32)
print(a)
# Out:
# [1 2 3]

# %%
b = np.array([[1.0,2.6,7.9], [4.1,5.2,6.3]])
print(b)
# Out:
# [[1.  2.6 7.9]
#  [4.1 5.2 6.3]]

# %%
# Dimension
a.ndim
# Out:
# 1

# %%
b. ndim
# Out:
# 2

# %%
# Shapes
a.shape
# Out:
# (3,)

# %%
b.shape
# Out:
# (2, 3)

# %%
# size
a.size
# Out:
# 3

# %%
b.size
# Out:
# 6

# %%
# itemsize
a.itemsize
# Out:
# 4

# %%
b.itemsize
# Out:
# 8

# %%
# total size
a.size * a.itemsize
# Out:
# 12

# %%
c=np.array([[[1,2],[4,5]],[[6,7],[8,9]]])
print(c)
# Out:
# [[[1 2]
#   [4 5]]
#
#  [[6 7]
#   [8 9]]]

# %%
c.shape
# Out:
# (2, 2, 2)

# %%
c[0]
# Out:
# array([[1, 2],
#        [4, 5]])

# %%
c[0][1]
# Out:
# array([4, 5])

# %%
c[0][1][1]
# Out:
# np.int64(5)
