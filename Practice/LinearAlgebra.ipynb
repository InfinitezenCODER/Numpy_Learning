# %%
import numpy as np

# %%
V1 = np.array([1,2,3])
V2 = np.array([5, 6, 7])
A = np.array([[1,2],[3,4]])
B = np.array([[6,7],[8,9]])

# %% [markdown]
# Matrix Multiplication :
# Use @ or matmul() for matrix multiplication .

# %%
C = A @ B
C = np.matmul(A,B)
print(C)
# Out:
# [[22 25]
#  [50 57]]

# %%
# Dot Product :
# Use np.dot() .
dot = np.dot(V1,V2)
print(dot)
# Out:
# 38

# %%
# Deteminant
I = np.identity(3)
print(np.linalg.det(I))
# Out:
# 1.0

# %%
AT = A.T
print(AT)
# Out:
# [[1 3]
#  [2 4]]

# %%
# Inverse Matrix
A_inv = np.linalg.inv(A)
print(A_inv)
# Out:
# [[-2.   1. ]
#  [ 1.5 -0.5]]

# %% [markdown]
# Advanced Linear Algebra

# %%
np.linalg.matrix_rank(A)
# Out:
# np.int64(2)

# %%
# norm = It measures the Length of the vector 
v = np.array([3,4])
np.linalg.norm(v)
# Out:
# np.float64(5.0)

# %%
eigenvalues, eigenvectors = np.linalg.eig(A)

print(eigenvalues)
print(eigenvectors)
# Out:
# [-0.37228132  5.37228132]
# [[-0.82456484 -0.41597356]
#  [ 0.56576746 -0.90937671]]

# %% [markdown]
# Statistics

# %%
stats = np.array([[1,2,3],[6,7,8]])
stats
# Out:
# array([[1, 2, 3],
#        [6, 7, 8]])

# %%
np.min(stats)
# Out:
# np.int64(1)

# %%
np.max(stats)
# Out:
# np.int64(8)

# %%
# axis = 0 means columnwise operation 
# axis = 1 means rowwise operation 
ax0 = np.mean(stats, axis = 0)
ax0
# Out:
# array([3.5, 4.5, 5.5])

# %%
ax1 = np.mean(stats, axis = 1)
ax1
# Out:
# array([2., 7.])
